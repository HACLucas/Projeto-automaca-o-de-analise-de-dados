# %%
import pyautogui
import time
import pandas
import openpyxl
import pyperclip
pyautogui.PAUSE = 1

#Abrir o navegador 
pyautogui.press("win")
pyautogui.write("chrome")
pyautogui.press("enter")
time.sleep(1.7)

#Acessar a base de dados
pyautogui.click(x=219, y=51)
link = "https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga"
pyautogui.write(link)
pyautogui.press("enter")

time.sleep(0.5)

#Baixar a base de dados
time.sleep(0.5)
pyautogui.click(x=401, y=315, clicks= 2)

pyautogui.click(x=1815, y=326)

pyautogui.click(x=1602, y=411)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pyautogui
#       2 import time
#       3 import pandas
#
# ModuleNotFoundError: No module named 'pyautogui'

# %%
#Abrir a base de dados

caminho_basedados = r"H:\Downloads\Vendas - Dez.xlsx"

tabela = pandas.read_excel(caminho_basedados)

faturamento = tabela["Valor Final"].sum()

quantidade_produtos = tabela["Quantidade"].sum()

#exibir a tabela na tela
display(tabela)
print(f"Faturamento: {faturamento}")
print(f"Quantidade de produtos vendidos: {quantidade_produtos}")
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
#Acessar o e-mail

pyautogui.hotkey("ctrl","t")
link_email = "https://mail.google.com/"
pyautogui.write(link_email)
pyautogui.press("enter")
time.sleep(3.5)

#Escrever e-mail
pyautogui.click(x=85, y=178)
time.sleep(3)

#para quem enviar
pyautogui.write("seuemail@gmail.com")
pyautogui.press("tab")#seleciona o e-mail
pyautogui.press("tab")#seleciona o campo asssunto
time.sleep(3)

#assunto do e-mail
pyperclip.copy("relatório de vendas")
pyautogui.hotkey("ctrl","v")#seleciona o corpo do e-mail
pyautogui.press("tab")

#mensagem do corpo do e-mail

texto = f"""
Prezados,

Segue o relatório de vendas mensal.

Faturamento: R${faturamento: ,.2f}

Quantidade de vendas: {quantidade_produtos: ,}

Qualquer duvida estou a disposição.

"""
pyperclip.copy(texto)
pyautogui.hotkey("ctrl","v")

#enviar

pyautogui.click(x=1292, y=998)

# %%
time.sleep(6)
print(pyautogui.position())
# Out:
# Point(x=493, y=274)
